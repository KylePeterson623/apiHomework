# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %%
#Sets the api url and desired information type
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Builds a partial query URL
query_url = f"{url}appid=25bc90a1196e6f153eece0bc0b0fc9eb&units={units}&q="

#Creates empty lists to append later
names = []
clouds = []
countries = []
dates = []
humidities = []
lats = []
lons = []
maxTemps = []
windSpds = []

#Sets variables to keep track of city and error numbers
cityNumber = 0
errorNumber = 0

#Loops through every city and saves desired data into lists
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        
        clouds.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lons.append(response['coord']['lon'])
        maxTemps.append(response['main']['temp_max'])
        windSpds.append(response['wind']['speed'])
        names.append(response['name'])
        
        #Creates and prints the city number alongside its associated city
        cityNumber += 1
        print(f"({cityNumber}): {city}")
        
    except KeyError:
        #Creates and prints the error number alongside its associated city
        errorNumber += 1
        print(f"ERROR {errorNumber}: {city}")


#Prints a summary of the for-loop
print("---------------------------------------")
print(f"{cityNumber} cities successfully logged")
print(f"{errorNumber} errors returned")
# Out:
# (1): nuuk
# (2): beringovskiy
# (3): cidreira
# ERROR 1: amderma
# (4): thunder bay
# (5): busselton
# (6): vaini
# (7): dikson
# (8): cape town
# (9): flinders
# (10): bethel
# (11): albany
# (12): narsaq
# (13): manjacaze
# (14): tuktoyaktuk
# (15): cabra
# (16): puerto ayora
# (17): hanmer springs
# (18): bahia de caraquez
# (19): mumford
# (20): geraldton
# (21): sao filipe
# (22): punta arenas
# (23): black diamond
# (24): qaqortoq
# (25): moose factory
# ERROR 2: mys shmidta
# (26): tyazhinskiy
# (27): sosnovoborsk
# (28): mehamn
# (29): sao miguel do araguaia
# (30): los llanos de aridane
# (31): zaragoza
# (32): ambulu
# (33): mataura
# ERROR 3: attawapiskat
# (34): port hedland
# (35): suluq
# (36): vestmannaeyjar
# ERROR 4: ndele
# (37): jamestown
# (38): hobart
# (39): broome
# (40): havre-saint-pierre
# (41): ushuaia
# ERROR 5: taolanaro
# (42): aplahoue
# (43): esperance
# (44): deputatskiy
# (45): hithadhoo
# (46): rikitea
# (47): klaksvik
# (48): sept-iles
# (49): linqu
# (50): quatre cocos
# (51): pangody
# (52): zaoyang
# (53): iqaluit
# (54): saint-philippe
# (55): mahebourg
# (56): upernavik
# (57): lata
# (58): nyurba
# (59): pisco
# (60): ulladulla
# (61): bandarbeyla
# (62): fortuna
# (63): las cruces
# ERROR 6: ondorhaan
# ERROR 7: barentsburg
# (64): avarua
# (65): mount isa
# (66): butaritari
# (67): kruisfontein
# (68): reni
# ERROR 8: vaitupu
# (69): mar del plata
# ERROR 9: acarau
# (70): morlaix
# (71): shumyachi
# (72): poum
# (73): faanui
# (74): havelock
# (75): necochea
# (76): qaanaaq
# (77): flin flon
# (78): vilyuysk
# (79): matagami
# (80): muisne
# (81): tuatapere
# (82): ribeira grande
# (83): nikolskoye
# (84): jardim
# (85): dosso
# (86): palmer
# (87): kapaa
# (88): lebu
# (89): jasper
# (90): saldanha
# (91): oranjestad
# (92): nosy varika
# (93): bathsheba
# (94): grindavik
# ERROR 10: belushya guba
# (95): olga
# (96): najran
# (97): talnakh
# (98): port alfred
# (99): tiksi
# (100): nelson bay
# (101): new norfolk
# (102): ponta do sol
# (103): perth
# (104): egvekinot
# (105): praia da vitoria
# (106): chokurdakh
# (107): provideniya
# ERROR 11: catamarca
# (108): chupaca
# (109): cap malheureux
# (110): tocopilla
# (111): georgetown
# (112): smithers
# (113): bluff
# (114): khatanga
# (115): guerrero negro
# (116): cherskiy
# ERROR 12: meyungs
# (117): atuona
# (118): atar
# (119): hilo
# (120): uppsala
# (121): yaan
# (122): barrow
# (123): road town
# (124): yellowknife
# (125): chuy
# (126): pochutla
# (127): huarmey
# (128): banda aceh
# (129): hermanus
# (130): coquimbo
# (131): mount gambier
# (132): atbasar
# (133): kavaratti
# (134): bredasdorp
# (135): pokhara
# (136): kodiak
# ERROR 13: tsihombe
# (137): norman wells
# (138): leningradskiy
# (139): pevek
# (140): sao joao da barra
# (141): arraial do cabo
# (142): usinsk
# (143): kaitangata
# (144): carnarvon
# (145): kaduqli
# ERROR 14: chlorakas
# (146): college
# (147): tasiilaq
# (148): ca mau
# ERROR 15: bengkulu
# (149): reforma
# ERROR 16: kytlym
# ERROR 17: mancio lima
# (150): canon city
# (151): solano
# (152): san vicente
# (153): clyde river
# (154): nuevo progreso
# (155): mayo
# (156): gunnedah
# (157): terrace
# (158): henties bay
# (159): goure
# ERROR 18: illoqqortoormiut
# (160): ishikawa
# (161): te anau
# (162): bako
# (163): fayaoue
# (164): wakkanai
# (165): ferme-neuve
# (166): anderson
# (167): khani
# (168): tartagal
# (169): mitsamiouli
# (170): manta
# ERROR 19: marcona
# (171): victoria
# ERROR 20: sakakah
# (172): bambous virieux
# (173): kuytun
# (174): jumla
# (175): vanino
# (176): ambon
# (177): ramnagar
# (178): ilulissat
# (179): realeza
# (180): thompson
# (181): rocha
# (182): bouar
# ERROR 21: eskasem
# (183): gat
# (184): yumen
# (185): saskylakh
# (186): khanpur
# (187): plouzane
# (188): san cristobal
# (189): lompoc
# (190): castro
# (191): port-gentil
# ERROR 22: acara
# (192): dunedin
# (193): burmakino
# ERROR 23: dolbeau
# (194): vanavara
# (195): kendari
# (196): tarabuco
# (197): kavieng
# (198): fare
# (199): samarai
# (200): juneau
# (201): airai
# (202): petatlan
# (203): diffa
# (204): trincomalee
# (205): ekhabi
# (206): skibbereen
# (207): santa maria da vitoria
# (208): caraquet
# (209): buala
# (210): sibolga
# (211): nijar
# (212): karratha
# (213): jacmel
# (214): cabo san lucas
# ERROR 24: nizhneyansk
# (215): serenje
# (216): souillac
# ERROR 25: korla
# (217): torbay
# (218): trairi
# (219): jaguarari
# (220): severiano melo
# (221): mogadishu
# (222): caravelas
# (223): santiago del estero
# (224): vostok
# ERROR 26: akyab
# (225): toamasina
# (226): imbituba
# (227): port elizabeth
# (228): dhidhdhoo
# ERROR 27: grand centre
# (229): novodugino
# (230): pelotas
# (231): sitka
# (232): waldoboro
# (233): robertsport
# ERROR 28: kollumerland
# (234): yurga
# (235): vao
# (236): yulara
# (237): esso
# (238): eureka
# (239): moerai
# (240): longyearbyen
# (241): hasaki
# (242): sambava
# (243): nedjo
# (244): okha
# ERROR 29: atsiki
# (245): birao
# (246): sechura
# (247): camacha
# (248): ostrovnoy
# (249): grand baie
# (250): noshiro
# (251): nemuro
# (252): namatanai
# ERROR 30: rawah
# ERROR 31: sentyabrskiy
# (253): la ronge
# (254): maibong
# (255): kodinsk
# (256): severo-kurilsk
# (257): berwick
# (258): prostejov
# (259): kindu
# (260): hirara
# (261): constitucion
# (262): lagos
# (263): conde
# (264): santa cruz
# (265): bilibino
# (266): east london
# (267): isangel
# (268): bensonville
# ERROR 32: one hundred mile house
# (269): villanueva
# (270): emba
# (271): comodoro rivadavia
# (272): sokoni
# ERROR 33: grand river south east
# (273): port augusta
# (274): umm kaddadah
# (275): milagres
# (276): tucupita
# (277): katsuura
# (278): pozo colorado
# (279): bismarck
# (280): nome
# ERROR 34: rudbar
# (281): acapulco
# (282): luderitz
# (283): kindersley
# (284): salym
# (285): paysandu
# (286): gushi
# (287): iquique
# (288): chifeng
# (289): barkhan
# (290): nikki
# (291): pio xii
# (292): salamanca
# (293): wanganui
# (294): nagahama
# (295): anadyr
# (296): christchurch
# (297): laguna
# (298): jiangkou
# (299): rioja
# (300): port lincoln
# (301): meadow lake
# (302): jose bonifacio
# (303): mamaku
# ERROR 35: promysla
# (304): caarapo
# (305): pacific grove
# (306): seoul
# (307): lorengau
# (308): petropavlovsk-kamchatskiy
# (309): san patricio
# ERROR 36: karaul
# (310): ilyich
# (311): tiruvidaimarudur
# (312): kafue
# (313): irbeyskoye
# (314): katherine
# (315): kristiansand
# (316): ariquemes
# (317): hohhot
# (318): ponta delgada
# ERROR 37: kuche
# ERROR 38: umzimvubu
# (319): lembeni
# (320): yar-sale
# (321): sayyan
# (322): hofn
# (323): upata
# (324): honningsvag
# (325): fomboni
# (326): fernandez
# (327): haghartsin
# (328): daru
# (329): ancud
# (330): pangoa
# (331): ulaangom
# (332): dongsheng
# (333): rindal
# (334): yatou
# (335): sinnamary
# (336): shahpur
# (337): wanning
# (338): viedma
# (339): abu dhabi
# (340): tazovskiy
# (341): portland
# (342): lasa
# (343): keetmanshoop
# (344): saint-tite
# ERROR 39: samusu
# (345): bukama
# (346): arroyo
# (347): paamiut
# (348): villa maria
# (349): bondo
# (350): araouane
# (351): anloga
# (352): cristobal obregon
# (353): shitanjing
# (354): chipinge
# (355): san rafael
# ERROR 40: saleaula
# (356): bima
# (357): kysyl-syr
# (358): todos santos
# ERROR 41: scottsburgh
# (359): soure
# (360): lavrentiya
# (361): isla vista
# (362): katangli
# (363): acajutla
# (364): ozernovskiy
# (365): vezirkopru
# (366): sur
# (367): maine-soroa
# (368): zeya
# (369): veere
# (370): mongo
# (371): armidale
# (372): filottrano
# (373): antalaha
# (374): kungurtug
# (375): verdun
# (376): palu
# (377): inhambane
# (378): olinda
# (379): sinaloa
# (380): port macquarie
# (381): umm lajj
# (382): barcelona
# (383): hami
# (384): buchanan
# (385): berlevag
# (386): marsabit
# (387): sola
# (388): tura
# (389): mezen
# (390): alofi
# (391): alihe
# (392): tilichiki
# (393): homnabad
# (394): sao jose dos campos
# (395): biak
# (396): linjiang
# (397): mollendo
# (398): sijunjung
# (399): luangwa
# (400): kaniama
# (401): morro bay
# (402): gamba
# (403): le port
# (404): grand gaube
# (405): bela
# (406): buraydah
# (407): marmaris
# (408): pahrump
# ERROR 42: lolua
# (409): beloha
# (410): isilkul
# (411): lagoa
# (412): fairbanks
# (413): cedar city
# (414): muzhi
# (415): aksarka
# (416): vila velha
# (417): kimbe
# (418): lakes entrance
# (419): bogale
# ERROR 43: alappuzha
# ERROR 44: tambopata
# (420): belmonte
# (421): padang
# (422): axim
# (423): tolbazy
# (424): pumiao
# ERROR 45: asau
# (425): okhotsk
# (426): cape coast
# (427): mayfield
# (428): candolim
# (429): taitung
# (430): kyren
# (431): izhma
# ERROR 46: tasbuget
# (432): sioux lookout
# (433): jagadhri
# (434): san calixto
# (435): tommot
# (436): kasimov
# (437): matinha
# (438): mokhotlong
# ERROR 47: solsvik
# (439): port moresby
# (440): waitati
# (441): takoradi
# (442): bone
# (443): saint george
# (444): remanso
# (445): bom jesus
# (446): boffa
# (447): dingle
# (448): cockburn town
# (449): nanortalik
# (450): freeport
# (451): tateyama
# (452): fukue
# (453): khartoum
# (454): west bay
# (455): baker city
# (456): oshikango
# (457): kitgum
# (458): garden city
# (459): kiunga
# (460): hualmay
# (461): solnechnyy
# (462): valdez
# (463): troy
# (464): santander
# (465): belinskiy
# (466): noumea
# (467): russkiy kameshkir
# (468): port blair
# (469): qingdao
# (470): kununurra
# (471): pitimbu
# (472): margate
# (473): roebourne
# (474): aksu
# (475): darhan
# (476): brewster
# (477): porto novo
# (478): guaimaro
# (479): mandera
# (480): tripoli
# (481): mozarlandia
# (482): nouadhibou
# (483): kharitonovo
# (484): olavarria
# (485): ocho rios
# (486): jesus carranza
# (487): doha
# (488): saint-georges
# (489): limbuhan
# ERROR 48: aktash
# (490): north bend
# (491): tramore
# (492): baykit
# (493): beinamar
# (494): murree
# ERROR 49: macaboboni
# (495): alibag
# (496): colares
# ERROR 50: nguiu
# (497): aljezur
# (498): kurilsk
# ERROR 51: bur gabo
# (499): qasigiannguit
# (500): tarakan
# (501): taoudenni
# (502): moussoro
# (503): prince rupert
# ERROR 52: safaga
# (504): hambantota
# (505): nishihara
# (506): tucuman
# (507): riyadh
# ERROR 53: samalaeulu
# (508): vytegra
# (509): mamakan
# (510): iquitos
# (511): charters towers
# ERROR 54: naftah
# (512): atambua
# (513): chengde
# (514): maragogi
# (515): quibal
# (516): muravlenko
# ERROR 55: barawe
# (517): kinsale
# (518): kahului
# ERROR 56: babanusah
# (519): montijo
# (520): edgewater
# (521): kusu
# (522): madras
# (523): matara
# (524): duba-yurt
# ERROR 57: sorvag
# (525): harper
# (526): opuwo
# (527): morehead
# (528): ouadda
# (529): ossora
# (530): columbus
# (531): mundgod
# (532): mandla
# (533): lakatoro
# (534): morros
# ERROR 58: maghama
# (535): wladyslawowo
# (536): la paz
# ERROR 59: buqayq
# ERROR 60: fulitun
# (537): rafai
# (538): tabas
# (539): linkoping
# (540): southampton
# (541): copiapo
# (542): feijo
# (543): svetlaya
# ERROR 61: rostaq
# (544): makokou
# (545): marsa matruh
# ---------------------------------------
# 545 cities successfully logged
# 61 errors returned

# %%
#Creates a dictionary using the list data gathered from the weather api
weatherDict = {"City": names,
              "Cloudiness": clouds,
              "Country": countries,
              "Date": dates,
              "Humidity": humidities,
              "Lat": lats,
              "Lng": lons,
              "Max Temp": maxTemps,
              "Wind Speed": windSpds}

#Converts the dictionary into a dataframe
weatherData = pd.DataFrame(weatherDict)

#Displays the dataframe
weatherData.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Nuuk          75      GL  1540641000        60  64.17  -51.74
# 1  Beringovskiy          64      RU  1540643002       100  63.05  179.32
# 2      Cidreira          92      BR  1540643003       100 -30.17  -50.22
# 3   Thunder Bay          90      CA  1540641600       100  48.41  -89.26
# 4     Busselton           0      AU  1540643003        93 -33.64  115.35
#
#    Max Temp  Wind Speed
# 0     41.00       31.09
# 1     16.73        4.27
# 2     63.08       17.69
# 3     42.80        4.70
# 4     65.51       18.70

# %%
#Saves the weather dataframe as a .csv
weatherData.to_csv("weatherData.csv")

# %%
#Creates the temperature scatterplot
plt.scatter(lats, maxTemps, marker="o", facecolors="teal", edgecolors="black", alpha = 0.75)

#Adds additional formatting to the temperature plot
plt.grid()
plt.title("City Latitude vs Max Temperature (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#Displays the temperature plot
plt.show()

# %%
#Creates the humidity scatterplot
plt.scatter(lats, humidities, marker="o", facecolors="teal", edgecolors="black", alpha = 0.75)

#Adds additional formatting to the humidity plot
plt.grid()
plt.title("City Latitude vs Humidity (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

#Displays the humidity plot
plt.show()

# %%
#Creates the cloudiness scatterplot
plt.scatter(lats, clouds, marker="o", facecolors="teal", edgecolors="black", alpha = 0.75)

#Adds additional formatting to the cloudiness plot
plt.grid()
plt.title("City Latitude vs Cloudiness (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Clouds (%)")

#Displays the cloudiness plot
plt.show()

# %%
#Creates the wind speed scatterplot
plt.scatter(lats, windSpds, marker="o", facecolors="teal", edgecolors="black", alpha = 0.75)

#Adds additional formatting to the wind speed plot
plt.grid()
plt.title("City Latitude vs Wind Speed (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#Displays the wind speed plot
plt.show()
